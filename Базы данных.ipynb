# %%
import sqlite3

# %%
help(sqlite3)
# Out:
# Help on package sqlite3:
#
# NAME
#     sqlite3
#
# DESCRIPTION
#     # pysqlite2/__init__.py: the pysqlite2 package.
#     #
#     # Copyright (C) 2005 Gerhard Häring <gh@ghaering.de>
#     #
#     # This file is part of pysqlite.
#     #
#     # This software is provided 'as-is', without any express or implied
#     # warranty.  In no event will the authors be held liable for any damages
#     # arising from the use of this software.
#     #
#     # Permission is granted to anyone to use this software for any purpose,
#     # including commercial applications, and to alter it and redistribute it
#     # freely, subject to the following restrictions:
#     #
#     # 1. The origin of this software must not be misrepresented; you must not
#     #    claim that you wrote the original software. If you use this software
#     #    in a product, an acknowledgment in the product documentation would be
#     #    appreciated but is not required.
# ...

# %%
con = sqlite3.connect('example.db')
cur = con.cursor()

# %%
# Create table
cur.execute('''CREATE TABLE books
               (book_id, Author, Title, publish_yaer)''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-4-44130243d9f6> in <module>
#       1 # Create table
#       2 cur.execute('''CREATE TABLE books
# ----> 3                (book_id, Author, Title, publish_yaer)''')
#
# OperationalError: table books already exists

# %%
# Insert a row of dat'a
cur.execute("INSERT INTO books VALUES ('01','Pushkin','Evgeny Onegin','1825'),('02','Gogol','Bii','1835')")


for row in cur.execute('SELECT * FROM books ORDER BY id'):
        print(row)
# Out:
# ('01', 'Pushkin', 'Evgeny Onegin', '1825')
# ('02', 'Gogol', 'Bii', '1835')

# %%
cur.execute("INSERT INTO books VALUES ('03','Pushkin','Руслан и Людмила','1825'),('02','Chehov','Дама с собачкой','1835')")

# %%
cur.execute('''CREATE TABLE Readers
               (reader_id, name)''')

# %%
cur.execute("INSERT INTO Readers VALUES ('1123','PavelSitko'),('1212','KateMeshersky')")

# %%
for row in cur.execute('SELECT * FROM Readers ORDER BY reader_id'):
        print(row)
# Out:
# ('1123', 'PavelSitko')
# ('1212', 'KateMeshersky')

# %%
cur.execute("DELETE from Readers where reader_id = 02 ")

# %%
cur.execute('''CREATE TABLE Records
               (reader_id, book_id PRIMARY KEY, taking_date, returning_date)''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-24-40a4d38ce3ca> in <module>
#       1 cur.execute('''CREATE TABLE Records
# ----> 2                (reader_id, book_id PRIMARY KEY, taking_date, returning_date)''')
#
# OperationalError: table Records already exists

# %%
cur.execute("INSERT INTO Readers VALUES ('1124','VaryaTomilova'),('1213','VeraTomilova')")

# %%
cur.execute("INSERT INTO Records VALUES ('1123','01','01.02.2022','01.03.2022'),('1212','02','22.12.2021','22.02.2022')")

# %%
cur.execute("INSERT INTO Records VALUES ('1123','03','01.02.2022','01.03.2022'),('1212','03','22.12.2021','22.02.2022')")

# %%
for row in cur.execute('SELECT * FROM Records ORDER BY reader_id'):
        print(row)
# Out:
# ('1123', '01', '01.02.2022', '01.03.2022')
# ('1123', '03', '01.02.2022', '01.03.2022')
# ('1212', '02', '22.12.2021', '22.02.2022')
# ('1212', '03', '22.12.2021', '22.02.2022')

# %%
for row in cur.execute('SELECT (book_id,Title) FROM Records,books ORDER BY book_id'):
        print(row)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-23-c342e13e82bc> in <module>
# ----> 1 for row in cur.execute('SELECT (book_id,Title) FROM (Records,books) ORDER BY book_id'):
#       2         print(row)
#
# OperationalError: row value misused

# %% [markdown]
# Запрос возвращает id и названия книг, находящихся в данный момент на руках у читателей

# %%
cur.execute("SELECT book_id,Title FROM Records WHERE book_id is not NULL",(book_id, name))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-a873b68f2c3b> in <module>
# ----> 1 cur.execute("SELECT book_id,Title FROM Records WHERE book_id is not NULL",(book_id, name))
#
# NameError: name 'book_id' is not defined

# %%
sqlite_select_query = """SELECT  (book_id,Title) FROM Records"""
cursor.execute(sqlite_select_query)
records = cursor.fetchall()
